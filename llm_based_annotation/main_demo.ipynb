# %%
import os
from utils import extract_body, tokenize, clean_tokens, decode
from utils import chunk_tokens, flatten_token_chunks
from utils import extract_few_shot_examples
from utils import select_few_shot 
from utils import merge_tokens_with_auto_labels, add_style_and_parent_to_auto_labels
from models import GPTAssistant
from process_chunks import process_chunks

# %%
# ---------- Define Hyperparameters ----------
min_tokens = 500
model_name = "gpt-4.1"

n_few_shot = 10  # Number of few-shot examples to use

# %% [markdown]
# #### Define the text to process, and where to save it

# %%
# File paths
project_root = r"C:\Users\zakga\OneDrive\Documents\code"
filename = "1999CanLII7320_annotated"
anno = "EG"
version = "v1"
html_path = fr"{project_root}\labelstudio\annotation\data\Documents_Annotés\{anno}\{filename}_{anno}_{version}.html"
output_dir = fr"{project_root}\labelstudio\annotation\data\Documents_Annotés\{anno}\{filename}_llm_{anno}"
os.makedirs(output_dir, exist_ok=True)

# Read HTML file
with open(html_path, 'r', encoding='utf-8') as file:
    html_content = file.read()
print(f"   ✓ HTML file loaded: {html_path}")
# Out:
#    ✓ HTML file loaded: C:\Users\zakga\OneDrive\Documents\code\labelstudio\annotation\data\Documents_Annotés\EG\1999CanLII7320_annotated_EG_v1.html

# %% [markdown]
# ### Process The HTML Content

# %%
# ---------- Extract body content ----------
body_content = extract_body(html_content)


# ---------- Tokenize body content ----------
tokens = tokenize(body_content)

# ---------- Extract body content ----------
normalized_cleaned_tokens = clean_tokens(html_tokens=tokens, normalize=True, keep_manual_label=True, keep_bookmarks=True)

# ---------- Chunk tokens ----------
token_chunk1, token_chunk2 = chunk_tokens(normalized_cleaned_tokens, min_tokens=min_tokens, stop_bookmark_separation=True)
# Out:
#    ✓ Found bookmark separator at index 23066
#    ✓ Splitting: 23066 tokens before, 31001 tokens after
#    ✓ Chunked tokens into 36 chunks (>= 500 tokens each)
#    ✓ Chunked tokens into 62 chunks (>= 500 tokens each)
#    ✓ Total chunks: 36 before + 62 after = 98

# %%
# ---------- Create few-shot examples ----------
few_shot_examples = extract_few_shot_examples(token_chunk1)
selected_few_shot_examples = select_few_shot(examples=few_shot_examples, n=n_few_shot)


# ---------- Initialize LLM model ----------
model = GPTAssistant(model_name)


# ---------- Process chunks ----------
processed_chunks = process_chunks(
    model=model,
    token_chunks=token_chunk2,
    few_shot_examples=selected_few_shot_examples,
    output_dir=output_dir,
    filename=filename
)
# Out:
#    ✓ Extracted 36 few-shot examples from chunks
#    ✓ Processing 62 texts with an LLM...
#    ✓ Using 10 few-shot examples
# processing document...:   0%|          | 0/62 [00:00<?, ?it/s]
# processing document...:   2%|▏         | 1/62 [00:10<10:42, 10.54s/it]
#    ✓ Consistent: 10 opening tags, 10 closing tags
# processing document...:   3%|▎         | 2/62 [00:24<12:43, 12.72s/it]
#    ✓ Consistent: 14 opening tags, 14 closing tags
# processing document...:   5%|▍         | 3/62 [00:27<08:10,  8.31s/it]
#    ✓ Consistent: 2 opening tags, 2 closing tags
# processing document...
/it]
#    ✓ Consistent: 2 opening tags, 2 closing tags
# processing document...:  77%|███████▋  | 48/62 [08:22<02:28, 10.60s/it]
#    ✓ Consistent: 36 opening tags, 36 closing tags
# processing document...:  79%|███████▉  | 49/62 [08:35<02:27, 11.32s/it]
#    ✓ Consistent: 24 opening tags, 24 closing tags
# processing document...:  81%|████████  | 50/62 [08:46<02:13, 11.12s/it]
#    ✓ Consistent: 11 opening tags, 11 closing tags
# processing document...:  82%|████████▏ | 51/62 [08:55<01:53, 10.34s/it]
#    ✓ Consistent: 10 opening tags, 10 closing tags
# processing document...:  84%|████████▍ | 52/62 [08:58<01:23,  8.33s/it]
#    ✓ Consistent: 6 opening tags, 6 closing tags
# processing document...:  85%|████████▌ | 53/62 [09:05<01:11,  7.92s/it]
#    ✓ Consistent: 7 opening tags, 7 closing tags
# processing document...:  87%|████████▋ | 54/62 [09:09<00:52,  6.61s/it]
#    ✓ Consistent: 2 opening tags, 2 closing tags
# processing document...:  89%|████████▊ | 55/62 [09:13<00:40,  5.79s/it]
#    ✓ Consistent: 4 opening tags, 4 closing tags
# processing document...:  90%|█████████ | 56/62 [09:21<00:39,  6.64s/it]
#    ✓ Consistent: 18 opening tags, 18 closing tags
# processing document...:  92%|█████████▏| 57/62 [09:24<00:28,  5.65s/it]
#    ✓ Consistent: 0 opening tags, 0 closing tags
# processing document...:  94%|█████████▎| 58/62 [09:32<00:24,  6.06s/it]
#    ✓ Consistent: 2 opening tags, 2 closing tags
# processing document...:  95%|█████████▌| 59/62 [09:36<00:16,  5.57s/it]
#    ✓ Consistent: 7 opening tags, 7 closing tags
# processing document...:  97%|█████████▋| 60/62 [09:45<00:13,  6.60s/it]
#    ✓ Consistent: 12 opening tags, 12 closing tags
# processing document...:  98%|█████████▊| 61/62 [09:53<00:07,  7.09s/it]
#    ✓ Consistent: 9 opening tags, 9 closing tags
# processing document...: 100%|██████████| 62/62 [09:58<00:00,  9.66s/it]
#    ✓ Consistent: 9 opening tags, 9 closing tags
#    ✓ AI processing completed
#    ✓ Enhanced texts saved to: C:\Users\zakga\OneDrive\Documents\code\labelstudio\annotation\data\Documents_Annotés\EG\1999CanLII7320_annotated_llm_EG\history_1999CanLII7320_annotated.json

# %% [markdown]
# ## Post Processing

# %%
# ---------- Merge all tokens ----------
body_chunked_processed =  token_chunk1 + processed_chunks
processed_tokens_flat = flatten_token_chunks(body_chunked_processed)


original_tokens = tokenize(html_content)
processed_html_content = merge_tokens_with_auto_labels(original_tokens, processed_tokens_flat)

processed_html = decode(processed_html_content)

print(f"\nMerged HTML length: {len(processed_html)}")

# ---------- Add style and parent to auto_label tags ----------
processed_html_content = add_style_and_parent_to_auto_labels(processed_html)
# Out:
#    ✓ Flattened 98 chunks into 55251 tokens
#
# Merged HTML length: 278831

# %%
# ---------- Save processed HTML to file ----------
with open(fr"{output_dir}\{filename}_llm_{anno}.html", 'w', encoding='utf-8') as f:
    f.write(processed_html_content)
print(f"   ✓ Processed HTML saved to: {output_dir}")
# Out:
#    ✓ Processed HTML saved to: C:\Users\zakga\OneDrive\Documents\code\labelstudio\annotation\data\Documents_Annotés\EG\1999CanLII7320_annotated_llm_EG
