# %%
import sys
import re
from pathlib import Path
from collections import defaultdict
from bs4 import BeautifulSoup

# Add utils to path
sys.path.append(str(Path.cwd().parent.parent / 'llm_based_annotation'))
from utils_extraction.html_utils import is_manual_label_tag
from utils_extraction.htmlLabel import HTMLLabel

# %%
# Define the three HTML files to analyze
from pathlib import Path
data_dir = Path.cwd().parent.parent / 'data' / 'Documents_Annotés'
final_annotated_dir = Path.cwd().parent.parent / 'data' / 'final' / 'Annotated'

html_files = [
    final_annotated_dir / '1997CanLII16226_ONCA_annotated_EG_revRL_tech.html',
    final_annotated_dir / '2021QCCA1675_annotated_EG_revRL_tech.html',
    final_annotated_dir /  '1989CanLII1415CITT_annotated_GL_revRL_tech.html',
    final_annotated_dir / '2001CanLII21117QCTDP_annotated_GL_revRL_tech.html',
    final_annotated_dir / "2019SCC65_annotated_EG_revRL_tech.html",
    final_annotated_dir / "2024NBKB203_annotated_VP_rev2RL_tech.html",
    final_annotated_dir / "2005QCCA437_LLMv1.3_Verified_GL_revRL_tech.html",
    final_annotated_dir / "2002SCC33_annotated_EG_revRL.html",
    final_annotated_dir / "1994CanLII4528NLCA_annotated_GL_revRL.html",
    final_annotated_dir / "2008CSC9_annotated_EG_revRL.html",
    final_annotated_dir / "2016NBOMB12_annotated_EG_revRL.html",






]

# Verify files exist
for f in html_files:
    print(f"{'✓' if f.exists() else '✗'} {f.name}")
# Out:
# ✓ 1997CanLII16226_ONCA_annotated_EG_revRL_tech.html
# ✓ 2021QCCA1675_annotated_EG_revRL_tech.html
# ✓ 1989CanLII1415CITT_annotated_GL_revRL_tech.html
# ✓ 2001CanLII21117QCTDP_annotated_GL_revRL_tech.html
# ✓ 2019SCC65_annotated_EG_revRL_tech.html
# ✓ 2024NBKB203_annotated_VP_rev2RL_tech.html
# ✓ 2005QCCA437_LLMv1.3_Verified_GL_revRL_tech.html
# ✓ 2002SCC33_annotated_EG_revRL.html
# ✓ 1994CanLII4528NLCA_annotated_GL_revRL.html
# ✓ 2008CSC9_annotated_EG_revRL.html

# %%
def extract_parent_level_annotations(html_content):
    """
    Extract all parent-level manual_label and auto_label annotations (where parent="").
    Returns a dict with keys: 'decision', 'legislation', 'secondary sources'
    Each value is a list of annotation dictionaries containing:
      - full_html: the complete annotation HTML
      - docid: document identifier
      - uri: resource URI
      - text_content: extracted text (no HTML tags)
      - sublabels: list of sublabel types found
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find all manual_label and auto_label tags with parent=""
    parent_labels = soup.find_all(['manual_label', 'auto_label'], attrs={'parent': ''})
    
    annotations = {
        'decision': [],
        'legislation': [],
        'secondary sources': []
    }
    
    for label in parent_labels:
        labelname = label.get('labelname', '')
        
        if labelname not in annotations:
            continue
        
        # Extract sublabels
        sublabels = []
        for sublabel in label.find_all(['manual_label', 'auto_label'], recursive=False):
            sublabel_name = sublabel.get('labelname', '')
            sublabels.append(sublabel_name)
        
        # Recursively get all sublabels (nested)
        all_sublabels = [sl.get('labelname', '') for sl in label.find_all(['manual_label', 'auto_label'])]
        
        annotation_data = {
            'full_html': str(label),
            'docid': label.get('docid', ''),
            'uri': label.get('uri', ''),
            'text_content': label.get_text(strip=True),
            'direct_sublabels': sublabels,
            'all_sublabels': all_sublabels
        }
        
        annotations[labelname].append(annotation_data)
    
    return annotations

# %%
# Process all files
all_annotations = {
    'decision': [],
    'legislation': [],
    'secondary sources': []
}

for html_file in html_files:
    print(f"\nProcessing: {html_file.name}")
    
    with open(html_file, 'r', encoding='utf-8') as f:
        html_content = f.read()
    
    annotations = extract_parent_level_annotations(html_content)
    
    # Aggregate results
    for label_type in ['decision', 'legislation', 'secondary sources']:
        count = len(annotations[label_type])
        print(f"  - {label_type}: {count} annotations")
        all_annotations[label_type].extend(annotations[label_type])

print("\n" + "="*60)
print("TOTAL ANNOTATIONS ACROSS ALL FILES:")
for label_type in ['decision', 'legislation', 'secondary sources']:
    print(f"  {label_type}: {len(all_annotations[label_type])}")
print("="*60)
# Out:
# Processing: 1997CanLII16226_ONCA_annotated_EG_revRL_tech.html
#   - decision: 249 annotations
#   - legislation: 359 annotations
#   - secondary sources: 15 annotations
#
# Processing: 2021QCCA1675_annotated_EG_revRL_tech.html
#   - decision: 54 annotations
#   - legislation: 45 annotations
#   - secondary sources: 1 annotations
#
# Processing: 1989CanLII1415CITT_annotated_GL_revRL_tech.html
#   - decision: 24 annotations
#   - legislation: 36 annotations
#   - secondary sources: 34 annotations
#
# Processing: 2001CanLII21117QCTDP_annotated_GL_revRL_tech.html
#   - decision: 63 annotations
#   - legislation: 250 annotations
#   - secondary sources: 11 annotations
#
# Processing: 2019SCC65_annotated_EG_revRL_tech.html
#   - decision: 1003 annotations
#   - legislation: 262 annotations
#   - secondary sources: 178 annotations
#
# Processing: 2024NBKB203_annotated_VP_rev2RL_tech.html
#   - decision: 149 annotations
#   - legislation: 68 annotations
#   - secondary sources: 27 annotations
#
# Processing: 2005QCCA437_LLMv1.3_Verified_GL_revRL_tech.html
#   - decision: 33 annotations
#   - legislation: 75 annotations
#   - secondary sources: 3 annotations
#
# Processing: 2002SCC33_annotated_EG_revRL.html
#   - decision: 254 annotations
#   - legislation: 45 annotations
#   - secondary sources: 29 annotations
#
# Processing: 1994CanLII4528NLCA_annotated_GL_revRL.html
#   - decision: 20 annotations
#   - legislation: 140 annotations
#   - secondary sources: 1 annotations
#
# Processing: 2008CSC9_annotated_EG_revRL.html
#   - decision: 307 annotations
#   - legislation: 134 annotations
#   - secondary sources: 43 annotations
#
# ============================================================
# TOTAL ANNOTATIONS ACROSS ALL FILES:
#   decision: 2156
#   legislation: 1414
#   secondary sources: 342
# ============================================================

# %%
print(f"DECISION ANNOTATIONS ({len(all_annotations['decision'])} total)\\n")
print("="*80)

for i, annotation in enumerate(all_annotations['decision'][:20], 1):  # Show first 20
    print(f"\n[{i}] DocID: {annotation['docid']}")
    print(f"    URI: {annotation['uri']}")
    print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
    print(f"    Text: {annotation['text_content'][:100]}...")
    print(f"    HTML Preview: {annotation['full_html'][:200]}...")

if len(all_annotations['decision']) > 20:
    print(f"\n... and {len(all_annotations['decision']) - 20} more decision annotations")
# Out:
# DECISION ANNOTATIONS (2156 total)\n
# ================================================================================
#
# [1] DocID: Church of Scientology ONCA 1997
#     URI: https://canlii.ca/t/6hxv
#     Sublabels: title
#     Text: R. v. Church of Scientology...
#     HTML Preview: <manual_label docid="Church of Scientology ONCA 1997" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/6hxv" verified="false"><manual...
#
# [2] DocID: Church of Scientology ONCA 1997
#     URI: https://canlii.ca/t/6hxv
#     Sublabels: citation
#     Text: 33 O.R. (3d) 65...
#     HTML Preview: <manual_label docid="Church of Scientology ONCA 1997" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/6hxv" verified="false"><manual...
#
# [3] DocID: Church of Scientology ONCA 1997
#     URI: https://canlii.ca/t/6hxv
#     Sublabels: citation
#     Text: [1997] O.J. No. 1548...
#     HTML Preview: <manual_label docid="Church of Scientology ONCA 1997" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/6hxv" verified="false"><manual...
#
# [4] DocID: Canadian Dredge & Dock
#     URI: https://canlii.ca/t/1fv17
#     Sublabels: citation, title
#     Text: Canadian Dredge & Dock Co. v. R.,[1985] 1 S.C.R. 662,19 C.C.C. (3d) 1,45 C.R. (3d) 289,19 D.L.R. (4t...
#     HTML Preview: <manual_label docid="Canadian Dredge &amp; Dock" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1fv17" verified="false"><manual_lab...
#
# [5] DocID: McNamara
#     URI: https://canlii.ca/t/gd1kv
#     Sublabels: citation
#     Text: affg(1981), 56 C.C.C.
# (2d) 193 (Ont. C.A.)...
#     HTML Preview: <manual_label docid="McNamara" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/gd1kv" verified="false">affg <manual_label labelname=...
#
# [6] DocID: Collins
#     URI: https://canlii.ca/t/1ftnd
#     Sublabels: citation, title
#     Text: R. v. Collins,[1987] 1 S.C.R. 265,28 C.R.R. 122,13
# B.C.L.R. (2d) 1,33 C.C.C. (3d) 1,56 C.R. (3d) 193...
#     HTML Preview: <manual_label docid="Collins" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1ftnd" verified="false"> <manual_label labelname="titl...
#
# [7] DocID: Carosella
#     URI: https://canlii.ca/t/1fr3p
#     Sublabels: citation, title
#     Text: apldR. v. Carosella (1997),41 C.R.R. (2d) 189,112 C.C.C. (3d) 289,142 D.L.R. (4th) 595,207 N.R. 321 ...
#     HTML Preview: <manual_label docid="Carosella" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1fr3p" verified="false">apld <manual_label labelname...
#
# [8] DocID: Andrews
#     URI: https://canlii.ca/t/1ft8q
#     Sublabels: citation, title
#     Text: Andrews
# v. Law Society of British Columbia,[1989] 1 S.C.R. 143,36 C.R.R. 193,34
# B.C.L.R. (2d) 273,25...
#     HTML Preview: <manual_label docid="Andrews" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1ft8q" verified="false"> <manual_label labelname="titl...
#
# [9] DocID: Irwin Toy
#     URI: https://canlii.ca/t/1ft6g
#     Sublabels: citation, title
#     Text: Irwin Toy Ltd. v. Quebec (Attorney General),[1989]
# 1 S.C.R. 927,39 C.R.R. 193,25 C.P.R. (3d) 417,58 ...
#     HTML Preview: <manual_label docid="Irwin Toy" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1ft6g" verified="false"> <manual_label labelname="ti...
#
# [10] DocID: Philippines
#     URI: https://canlii.ca/t/1npp0
#     Sublabels: citation, title
#     Text: Philippines (Republic) v. Pacificador (1993),14 O.R. (3d)
# 321,16 C.R.R. (2d) 299,83 C.C.C. (3d) 210,...
#     HTML Preview: <manual_label docid="Philippines" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1npp0" verified="false"><manual_label labelname="t...
#
# [11] DocID: Big M Drug Mart
#     URI: https://canlii.ca/t/1fv2b
#     Sublabels: citation, title
#     Text: R. v.
# Big M Drug Mart Ltd.,[1985] 1 S.C.R. 295,13 C.R.R. 64,37 Alta. L.R. (2d) 97,60 A.R. 161,18 C.C...
#     HTML Preview: <manual_label docid="Big M Drug Mart" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1fv2b" verified="false"> <manual_label labelna...
#
# [12] DocID: Church of Scientology ONSC-1 1992
#     URI: None
#     Sublabels: citation, title
#     Text: R. v. Church of Scientology (1992),9 C.R.R. (2d)
# 196 (Ont. Gen. Div.)...
#     HTML Preview: <manual_label docid="Church of Scientology ONSC-1 1992" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="None" verified="false"><manual_label labelname="...
#
# [13] DocID: Church of Scientology ONSC-2 1992
#     URI: https://canlii.ca/t/gczln
#     Sublabels: citation, title
#     Text: R. v. Church of Scientology (1992),9 C.R.R. (2d) 220
# (Ont. Gen. Div.)...
#     HTML Preview: <manual_label docid="Church of Scientology ONSC-2 1992" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/gczln" verified="false"><man...
#
# [14] DocID: Church of Scientology ONSC-3 1992
#     URI: https://canlii.ca/t/g9xd1
#     Sublabels: citation, title
#     Text: R. v. Church of Scientology (1992),9 C.R.R. (2d) 232 (Ont.
# Gen. Div.)...
#     HTML Preview: <manual_label docid="Church of Scientology ONSC-3 1992" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/g9xd1" verified="false"><man...
#
# [15] DocID: Zaharia ONCA 1987
#     URI: https://canlii.ca/t/1npn2
#     Sublabels: citation, title
#     Text: R. v. Church of Scientology; R. v. Zaharia (1987),30 C.R.R. 238,31 C.C.C. (3d) 449,18 O.A.C. 321 (C....
#     HTML Preview: <manual_label docid="Zaharia ONCA 1987" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1npn2" verified="false"> <manual_label label...
#
# [16] DocID: Edwards Books & Art
#     URI: https://canlii.ca/t/1ftpt
#     Sublabels: citation, title
#     Text: R. v. Edwards Books &
# Art Ltd.,[1986] 2 S.C.R. 713,28 C.R.R. 1,30 C.C.C. (3d) 385,87 C.L.L.C.
# 14,001...
#     HTML Preview: <manual_label docid="Edwards Books &amp; Art" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1ftpt" verified="false"><manual_label ...
#
# [17] DocID: Goldhart
#     URI: https://canlii.ca/t/1fr8m
#     Sublabels: citation, title
#     Text: R. v. Goldhart,[1996] 2 S.C.R. 463,37 C.R.R. (2d) 1,28 O.R.
# (3d) 480n,107 C.C.C. (3d) 481,48 C.R. (4...
#     HTML Preview: <manual_label docid="Goldhart" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1fr8m" verified="false"><manual_label labelname="titl...
#
# [18] DocID: Morgentaler
#     URI: https://canlii.ca/t/1ftjt
#     Sublabels: citation, title
#     Text: R. v. Morgentaler,[1988] 1 S.C.R. 30,31 C.R.R. 1,37 C.C.C. (3d)
# 449,62 C.R. (3d) 1,44 D.L.R. (4th) 3...
#     HTML Preview: <manual_label docid="Morgentaler" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1ftjt" verified="false"><manual_label labelname="t...
#
# [19] DocID: S. (R.J.)
#     URI: https://canlii.ca/t/1frmw
#     Sublabels: citation, title
#     Text: R. v. S. (R.J.),[1995] 1 S.C.R. 451,26 C.R.R. (2d) 1,96 C.C.C. (3d) 1,36 C.R. (4th) 1,121 D.L.R. (4t...
#     HTML Preview: <manual_label docid="S. (R.J.)" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1frmw" verified="false"> <manual_label labelname="ti...
#
# [20] DocID: Sherratt
#     URI: https://canlii.ca/t/1fslt
#     Sublabels: citation, title
#     Text: R. v.
# Sherratt,[1991] 1 S.C.R. 509,63 C.C.C. (3d) 193,3 C.R. (4th) 129,73 Man. R.
# (2d) 161,122 N.R. ...
#     HTML Preview: <manual_label docid="Sherratt" labelname="decision" parent="" style="background-color: rgb(106, 163, 255); color: black;" uri="https://canlii.ca/t/1fslt" verified="false"> <manual_label labelname="tit...
#
# ... and 2136 more decision annotations

# %%
print(f"LEGISLATION ANNOTATIONS ({len(all_annotations['legislation'])} total)\\n")
print("="*80)

for i, annotation in enumerate(all_annotations['legislation'][:20], 1):  # Show first 20
    print(f"\n[{i}] DocID: {annotation['docid']}")
    print(f"    URI: {annotation['uri']}")
    print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
    print(f"    Text: {annotation['text_content'][:100]}...")
    print(f"    HTML Preview: {annotation['full_html'][:200]}...")

if len(all_annotations['legislation']) > 20:
    print(f"\n... and {len(all_annotations['legislation']) - 20} more legislation annotations")
# Out:
# LEGISLATION ANNOTATIONS (1414 total)\n
# ================================================================================
#
# [1] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [2] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 8ofCharter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [3] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian Charter of
# Rights and Freedoms,ss. 8,24(2)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"> <manual_label labelname="ti...
#
# [4] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [5] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 1ofCharter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"> <manual_label fragmentid="s...
#
# [6] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian Charter of Rights and Freedoms,ss. 1,2(b)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [7] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [8] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian
# Charter of Rights and Freedoms,ss. 7,11(d)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [9] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [10] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian Charter of Rights
# and Freedoms,s. 15(1)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [11] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [12] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 11(f)ofCharter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [13] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian Charter of Rights
# and Freedoms,s. 11(f)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"> <manual_label labelname="ti...
#
# [14] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 2(a)ofCharter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [15] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: fragment
#     Text: s. 1...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [16] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: Canadian Charter of Rights and Freedoms,ss. 1,2(a)...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [17] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 8of theCanadian
# Charter of Rights and Freedoms...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [18] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title, fragment
#     Text: s. 24(2)of theCharter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label fragmentid="se...
#
# [19] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# [20] DocID: Charter
#     URI: https://canlii.ca/t/ldsx
#     Sublabels: title
#     Text: Charter...
#     HTML Preview: <manual_label docid="Charter" labelname="legislation" parent="" style="background-color: rgb(118, 206, 222); color: black;" uri="https://canlii.ca/t/ldsx" verified="false"><manual_label labelname="tit...
#
# ... and 1394 more legislation annotations

# %%
print(f"SECONDARY SOURCE ANNOTATIONS ({len(all_annotations['secondary sources'])} total)\\n")
print("="*80)

if len(all_annotations['secondary sources']) == 0:
    print("No secondary source annotations found in the analyzed files.")
else:
    for i, annotation in enumerate(all_annotations['secondary sources'][:20], 1):
        print(f"\n[{i}] DocID: {annotation['docid']}")
        print(f"    URI: {annotation['uri']}")
        print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
        print(f"    Text: {annotation['text_content'][:100]}...")
        print(f"    HTML Preview: {annotation['full_html'][:200]}...")
    
    if len(all_annotations['secondary sources']) > 20:
        print(f"\n... and {len(all_annotations['secondary sources']) - 20} more secondary source annotations")
# Out:
# SECONDARY SOURCE ANNOTATIONS (342 total)\n
# ================================================================================
#
# [1] DocID: Study of the Constitution
#     URI: None
#     Sublabels: title, authors, source, fragment
#     Text: Dicey,Introduction to the Study of the Law of the Constitution,10th ed.
# (1959),p. 193...
#     HTML Preview: <manual_label docid="Study of the Constitution" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labelname="...
#
# [2] DocID: The Stranger in our Midst
#     URI: None
#     Sublabels: title, authors, source
#     Text: Head, I., "The Stranger in our Midst: A Sketch of the Legal
# Status of the Alien in Canada"(1964), Ca...
#     HTML Preview: <manual_label docid="The Stranger in our Midst" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"> <manual_label labelname=...
#
# [3] DocID: Reform of the Criminal Jury
#     URI: https://canlii.ca/t/2blz
#     Sublabels: title, authors, source, fragment
#     Text: Petersen,
# C.,Institutionalized Racism: The Need for Reform of the Criminal Jury
# Selection Process) (...
#     HTML Preview: <manual_label docid="Reform of the Criminal Jury" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="https://canlii.ca/t/2blz" verified="false"><ma...
#
# [4] DocID: The Criminal Responsability of Churches
#     URI: https://canlii.ca/t/7nf1w
#     Sublabels: title, authors, source, fragment
#     Text: Russell, D.,
# "Paedophilia: The Criminal Responsibility of Canada's Churches"(1992), 15 Dalhousie L.J...
#     HTML Preview: <manual_label docid="The Criminal Responsability of Churches" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="https://canlii.ca/t/7nf1w" verifie...
#
# [5] DocID: Jury Selection
#     URI: None
#     Sublabels: title, authors, source
#     Text: Schulman and
# Meyers, ["Jury Selection", inStudies on the Jury, Law Reform
# Commission of Canada (1979...
#     HTML Preview: <manual_label docid="Jury Selection" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labelname="authors" pa...
#
# [6] DocID: Jury Selection
#     URI: None
#     Sublabels: fragment
#     Text: p. 408...
#     HTML Preview: <manual_label docid="Jury Selection" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label fragmentid="p 408" lab...
#
# [7] DocID: The Stranger in our Midst
#     URI:
#     Sublabels: title, authors
#     Text: Ivan Head,
# "The Stranger in our Midst: A Sketch of the Legal Status of the Alien in
# Canada",...
#     HTML Preview: <manual_label docid="The Stranger in our Midst" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="" verified="false"><manual_label labelname="auth...
#
# [8] DocID: Shorter Oxford English Dictionary
#     URI: None
#     Sublabels: title
#     Text: Shorter Oxford
# English Dictionary (1959)...
#     HTML Preview: <manual_label docid="Shorter Oxford English Dictionary" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label lab...
#
# [9] DocID: Study of the Constitution
#     URI: None
#     Sublabels: authors
#     Text: Dicey...
#     HTML Preview: <manual_label docid="Study of the Constitution" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labelname="...
#
# [10] DocID: Study of the Constitution
#     URI: None
#     Sublabels: title, authors, source, fragment
#     Text: Dicey,Introduction to the Study of the Law of the Constitution,10th ed.
# (1959), atp. 193...
#     HTML Preview: <manual_label docid="Study of the Constitution" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labelname="...
#
# [11] DocID: The Criminal Responsability of Churches
#     URI: https://canlii.ca/t/7nf1w
#     Sublabels: authors
#     Text: Dawn Russell...
#     HTML Preview: <manual_label docid="The Criminal Responsability of Churches" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="https://canlii.ca/t/7nf1w" verifie...
#
# [12] DocID: The Criminal Responsability of Churches
#     URI: https://canlii.ca/t/7nf1w
#     Sublabels: title, source, fragment
#     Text: Paedophilia:
# The Criminal Responsibility of Canada's Churches"(1992), 15 Dalhousie
# L.J. 380atp. 394...
#     HTML Preview: <manual_label docid="The Criminal Responsability of Churches" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="https://canlii.ca/t/7nf1w" verifie...
#
# [13] DocID: The Evolving Law
#     URI: None
#     Sublabels: title, authors, source, fragment
#     Text: Henry Hansmannobserves in "The
# Evolving Law of Nonprofit Organizations: Do Current Trends Make Good
# ...
#     HTML Preview: <manual_label docid="The Evolving Law" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labelname="authors" ...
#
# [14] DocID: The Evolving Law
#     URI: None
#     Sublabels: fragment
#     Text: pp. 819-20...
#     HTML Preview: <manual_label docid="The Evolving Law" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label fragmentid="p 819 - ...
#
# [15] DocID: Reform of the Criminal Jury
#     URI: https://canlii.ca/t/2blz
#     Sublabels: title, authors, source, fragment
#     Text: C. Petersen, "Institutionalized Racism: The Need for Reform of the
# Criminal Jury Selection Process"(...
#     HTML Preview: <manual_label docid="Reform of the Criminal Jury" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="https://canlii.ca/t/2blz" verified="false"><ma...
#
# [16] DocID: Recourse Against Civil Judgments
#     URI: None
#     Sublabels: title, authors, source, fragment
#     Text: John Anthony Jolowicz, “Introduction — Recourse Against
# Civil Judgments in the European Union: A Com...
#     HTML Preview: <manual_label docid="Recourse Against Civil Judgments" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_label labe...
#
# [17] DocID: New Standard Dictionary English Language
#     URI: None
#     Sublabels: title
#     Text: Funk
# & Wagnalls New Standard Dictionary of the English Language...
#     HTML Preview: <manual_label docid="New Standard Dictionary English Language" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_la...
#
# [18] DocID: The Oxford English Dictionary
#     URI: None
#     Sublabels: title, source
#     Text: The Oxford
# English Dictionary(Second Edition)...
#     HTML Preview: <manual_label docid="The Oxford English Dictionary" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><u></u><manual_label ...
#
# [19] DocID: Black's Law Dictionary
#     URI: None
#     Sublabels: title, source
#     Text: Black's Law Dictionary(Revised
# Fourth Edition)...
#     HTML Preview: <manual_label docid="Black's Law Dictionary" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><u></u><manual_label labelna...
#
# [20] DocID: The Houghton Mifflin Canadian Dictionary
#     URI: None
#     Sublabels: title
#     Text: The Houghton Mifflin Canadian Dictionary of the English
# Language...
#     HTML Preview: <manual_label docid="The Houghton Mifflin Canadian Dictionary" labelname="secondary sources" parent="" style="background-color: rgb(39, 143, 227); color: white;" uri="None" verified="false"><manual_la...
#
# ... and 322 more secondary source annotations

# %%
from collections import Counter

def analyze_sublabel_patterns(annotations, label_type):
    """Analyze which sublabels appear and in what patterns."""
    
    sublabel_counts = Counter()
    pattern_counts = Counter()
    
    for ann in annotations:
        # Count individual sublabels
        for sublabel in ann['all_sublabels']:
            sublabel_counts[sublabel] += 1
        
        # Count patterns (combinations of sublabels)
        pattern = tuple(sorted(set(ann['all_sublabels'])))
        pattern_counts[pattern] += 1
    
    print(f"\n{label_type.upper()} - SUBLABEL ANALYSIS")
    print("="*60)
    
    print("\nMost common sublabels:")
    for sublabel, count in sublabel_counts.most_common(10):
        print(f"  {sublabel}: {count}")
    
    print("\nMost common sublabel patterns:")
    for pattern, count in pattern_counts.most_common(10):
        print(f"  {pattern}: {count}")
    
    return sublabel_counts, pattern_counts

# Analyze each type
for label_type in ['decision', 'legislation', 'secondary sources']:
    if all_annotations[label_type]:
        analyze_sublabel_patterns(all_annotations[label_type], label_type)
# Out:
# DECISION - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   title: 1769
#   citation: 1648
#   fragment: 1128
#   source: 2
#
# Most common sublabel patterns:
#   ('citation', 'title'): 634
#   ('title',): 440
#   ('fragment', 'title'): 369
#   ('fragment',): 336
#   ('citation', 'fragment', 'title'): 317
#   ('citation',): 43
#   (): 11
#   ('citation', 'fragment'): 5
#   ('fragment', 'source', 'title'): 1
#
# LEGISLATION - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   fragment: 1192
#   title: 846
#   citation: 145
#
# Most common sublabel patterns:
#   ('fragment',): 551
#   ('fragment', 'title'): 421
#   ('title',): 297
#   ('citation', 'fragment', 'title'): 62
#   ('citation', 'title'): 53
#   ('citation',): 20
#   ('citation', 'fragment'): 8
#   (): 2
#
# SECONDARY SOURCES - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   authors: 279
#   title: 254
#   source: 213
#   fragment: 169
#   citation: 1
#
# Most common sublabel patterns:
#   ('authors', 'source', 'title'): 97
#   ('authors', 'fragment', 'source', 'title'): 86
#   ('authors', 'fragment'): 41
#   ('authors',): 34
#   ('source', 'title'): 19
#   ('title',): 17
#   ('fragment',): 15
#   ('authors', 'title'): 11
#   ('fragment', 'source', 'title'): 10
#   ('authors', 'fragment', 'title'): 10

# %%
# Create clean lists for each category
decision_list = all_annotations['decision']
legislation_list = all_annotations['legislation']
secondary_source_list = all_annotations['secondary sources']

print(f"Created lists:")
print(f"  - decision_list: {len(decision_list)} items")
print(f"  - legislation_list: {len(legislation_list)} items")
print(f"  - secondary_source_list: {len(secondary_source_list)} items")
print("\nThese lists are now available for further analysis in subsequent cells.")
# Out:
# Created lists:
#   - decision_list: 2156 items
#   - legislation_list: 1414 items
#   - secondary_source_list: 342 items
#
# These lists are now available for further analysis in subsequent cells.

# %%
import pandas as pd

def calculate_component_coverage(decision_list, legislation_list, secondary_source_list):
    """
    Calculate the percentage of annotations containing each component type.
    Returns a DataFrame for easy visualization.
    """
    
    # Define components to track
    components = ['Title', 'Citation', 'Fragment', 'Source', 'Authors']
    component_keys = ['title', 'citation', 'fragment', 'source', 'authors']
    
    # Count occurrences for each list
    def count_components(annotation_list, components_to_check):
        counts = {comp: 0 for comp in components_to_check}
        for annotation in annotation_list:
            sublabels = annotation['all_sublabels']
            for comp_key in components_to_check:
                if comp_key in sublabels:
                    counts[comp_key] += 1
        return counts
    
    # Get counts for each category
    decision_counts = count_components(decision_list, component_keys)
    legislation_counts = count_components(legislation_list, component_keys)
    secondary_counts = count_components(secondary_source_list, component_keys)
    
    # Calculate percentages
    decision_pcts = {k: (v / len(decision_list) * 100) if len(decision_list) > 0 else 0 
                     for k, v in decision_counts.items()}
    legislation_pcts = {k: (v / len(legislation_list) * 100) if len(legislation_list) > 0 else 0 
                        for k, v in legislation_counts.items()}
    secondary_pcts = {k: (v / len(secondary_source_list) * 100) if len(secondary_source_list) > 0 else 0 
                      for k, v in secondary_counts.items()}
    
    # Create a results dictionary
    results = {
        'Component': components,
        'Decisions': [decision_pcts[k] for k in component_keys],
        'Legislation': [legislation_pcts[k] for k in component_keys],
        'Secondary Sources': [secondary_pcts[k] for k in component_keys]
    }
    
    df = pd.DataFrame(results)
    
    # Print summary information
    print("COMPONENT COVERAGE ANALYSIS")
    print("="*80)
    print(f"\nDataset sizes:")
    print(f"  - Decisions:           n = {len(decision_list)}")
    print(f"  - Legislation:         n = {len(legislation_list)}")
    print(f"  - Secondary Sources:   n = {len(secondary_source_list)}")
    
    print(f"\nComponent Coverage Percentages:")
    print("-"*80)
    
    # Format and display the table
    print(f"{'Component':<20} {'Decisions':<15} {'Legislation':<15} {'Sec. Sources':<15}")
    print(f"{'':20} {'(n='+str(len(decision_list))+')':<15} {'(n='+str(len(legislation_list))+')':<15} {'(n='+str(len(secondary_source_list))+')':<15}")
    print("-"*80)
    
    for idx, row in df.iterrows():
        comp = row['Component']
        dec = row['Decisions']
        leg = row['Legislation']
        sec = row['Secondary Sources']
        
        # Format as percentages with 1 decimal place
        dec_str = f"{dec:.1f}%" if dec > 0 else "---"
        leg_str = f"{leg:.1f}%" if leg > 0 else "---"
        sec_str = f"{sec:.1f}%" if sec > 0 else "---"
        
        print(f"{comp:<20} {dec_str:<15} {leg_str:<15} {sec_str:<15}")
    
    print("="*80)
    
    return df

# Calculate and display the coverage table
coverage_df = calculate_component_coverage(decision_list, legislation_list, secondary_source_list)
# Out:
# COMPONENT COVERAGE ANALYSIS
# ================================================================================
#
# Dataset sizes:
#   - Decisions:           n = 2156
#   - Legislation:         n = 1414
#   - Secondary Sources:   n = 342
#
# Component Coverage Percentages:
# --------------------------------------------------------------------------------
# Component            Decisions       Legislation     Sec. Sources
#                      (n=2156)        (n=1414)        (n=342)
# --------------------------------------------------------------------------------
# Title                81.7%           58.9%           73.4%
# Citation             46.3%           10.1%           0.3%
# Fragment             47.7%           73.7%           47.7%
# Source               0.0%            ---             62.0%
# Authors              ---             ---             81.6%
# ================================================================================

# %%
def show_pattern_deconstruction_with_percentages(annotations, label_type):
    """
    Show the most common sublabel patterns (deconstructed) in order with percentages.
    """
    from collections import Counter
    
    pattern_counts = Counter()
    total_annotations = len(annotations)
    
    for ann in annotations:
        # Create an ordered tuple of unique sublabels to represent the construction
        sublabels = ann['all_sublabels']
        if sublabels:
            # Get the ordered tuple as it appears (preserving order of appearance)
            pattern = tuple(sublabels)
            pattern_counts[pattern] += 1
    
    print(f"\n{label_type.upper()} - DECONSTRUCTION PATTERNS (Ordered with Percentages)")
    print("="*100)
    print(f"Total annotations: {total_annotations}\n")
    
    if not pattern_counts:
        print("No patterns found.")
        return
    
    # Sort by frequency (descending)
    sorted_patterns = pattern_counts.most_common()
    
    # Print as a formatted table
    print(f"{'Rank':<6} {'Count':<8} {'%':<8} {'Pattern (in order of appearance)':<70}")
    print("-"*100)
    
    for rank, (pattern, count) in enumerate(sorted_patterns, 1):
        percentage = (count / total_annotations) * 100
        pattern_str = " → ".join(pattern)
        print(f"{rank:<6} {count:<8} {percentage:>6.1f}% {pattern_str:<70}")

# Show deconstruction patterns for each annotation type
print("\n" + "="*100)
print("PATTERN DECONSTRUCTION ANALYSIS WITH PERCENTAGES")
print("="*100)

for label_type in ['decision', 'legislation', 'secondary sources']:
    if all_annotations[label_type]:
        show_pattern_deconstruction_with_percentages(all_annotations[label_type], label_type)
        print()  # Extra line between sections
# Out:
# ====================================================================================================
# PATTERN DECONSTRUCTION ANALYSIS WITH PERCENTAGES
# ====================================================================================================
#
# DECISION - DECONSTRUCTION PATTERNS (Ordered with Percentages)
# ====================================================================================================
# Total annotations: 1575
#
# Rank   Count    %        Pattern (in order of appearance)
# ----------------------------------------------------------------------------------------------------
# ('title',)
# 1      337        21.4% title
# ('title', 'fragment')
# 2      284        18.0% title → fragment
# ('title', 'citation', 'citation')
# 3      211        13.4% title → citation → citation
# ('title', 'citation')
# 4      176        11.2% title → citation
# ('fragment',)
# 5      174        11.0% fragment
# ('title', 'citation', 'fragment')
# 6      138         8.8% title → citation → fragment
# ('title', 'citation', 'citation', 'fragment')
# 7      82          5.2% title → citation → citation → fragment
# ('citation',)
# 8      24          1.5% citation
# ('title', 'fragment', 'fragment')
# 9      22          1.4% title → fragment → fragment
# ('fragment', 'fragment')
# 10     18          1.1% fragment → fragment
# ('title', 'citation', 'fragment', 'citation', 'fragment')
# 11     11          0.7% title → citation → fragment → citation → fragment
# ('title', 'citation', 'citation', 'fragment', 'fragment')
# 12     10          0.6% title → citation → citation → fragment → fragment
# ('title', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation')
# 13     9           0.6% title → citation → citation → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation', 'citation')
# 14     7           0.4% title → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation')
# 15     7           0.4% title → citation → citation → citation → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation', 'citation', 'citation')
# 16     6           0.4% title → citation → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation')
# 17     4           0.3% title → citation → citation → citation → citation → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation', 'citation')
# 18     4           0.3% title → citation → citation → citation → citation → citation → citation → citation → citation → citation
# ('title', 'citation', 'citation', 'citation')
# 19     4           0.3% title → citation → citation → citation
# ('title', 'citation', 'fragment', 'fragment')
# 20     4           0.3% title → citation → fragment → fragment
# ('citation', 'citation')
# 21     3           0.2% citation → citation
# ('title', 'citation', 'fragment', 'citation')
# 22     3           0.2% title → citation → fragment → citation
# ('citation', 'fragment')
# 23     3           0.2% citation → fragment
# ('title', 'citation', 'citation', 'title', 'fragment')
# 24     3           0.2% title → citation → citation → title → fragment
# ('title', 'fragment', 'fragment', 'fragment')
# 25     3           0.2% title → fragment → fragment → fragment
# ('fragment', 'fragment', 'fragment', 'fragment')
# 26     2           0.1% fragment → fragment → fragment → fragment
# ('fragment', 'fragment', 'fragment')
# 27     2           0.1% fragment → fragment → fragment
# ('title', 'citation', 'citation', 'fragment', 'fragment', 'fragment')
# 28     2           0.1% title → citation → citation → fragment → fragment → fragment
# ('title', 'citation', 'title')
# 29     2           0.1% title → citation → title
# ('title', 'citation', 'title', 'citation', 'citation', 'citation', 'citation', 'citation')
# 30     1           0.1% title → citation → title → citation → citation → citation → citation → citation
# ('fragment', 'title')
# 31     1           0.1% fragment → title
# ('title', 'citation', 'title', 'citation')
# 32     1           0.1% title → citation → title → citation
# ('citation', 'citation', 'citation', 'citation', 'citation', 'citation')
# 33     1           0.1% citation → citation → citation → citation → citation → citation
# ('citation', 'citation', 'citation', 'citation', 'citation')
# 34     1           0.1% citation → citation → citation → citation → citation
# ('title', 'citation', 'fragment', 'fragment', 'fragment')
# 35     1           0.1% title → citation → fragment → fragment → fragment
# ('title', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment')
# 36     1           0.1% title → fragment → fragment → fragment → fragment → fragment
# ('title', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment')
# 37     1           0.1% title → fragment → fragment → fragment → fragment → fragment → fragment
# ('title', 'source', 'source', 'fragment')
# 38     1           0.1% title → source → source → fragment
#
#
# LEGISLATION - DECONSTRUCTION PATTERNS (Ordered with Percentages)
# ====================================================================================================
# Total annotations: 1095
#
# Rank   Count    %        Pattern (in order of appearance)
# ----------------------------------------------------------------------------------------------------
# ('fragment',)
# 1      418        38.2% fragment
# ('fragment', 'title')
# 2      270        24.7% fragment → title
# ('title',)
# 3      234        21.4% title
# ('title', 'citation')
# 4      32          2.9% title → citation
# ('fragment', 'fragment', 'title')
# 5      20          1.8% fragment → fragment → title
# ('citation',)
# 6      19          1.7% citation
# ('title', 'citation', 'fragment')
# 7      17          1.6% title → citation → fragment
# ('fragment', 'title', 'citation')
# 8      16          1.5% fragment → title → citation
# ('fragment', 'fragment')
# 9      15          1.4% fragment → fragment
# ('title', 'fragment')
# 10     9           0.8% title → fragment
# ('title', 'citation', 'fragment', 'fragment')
# 11     6           0.5% title → citation → fragment → fragment
# ('title', 'fragment', 'fragment')
# 12     5           0.5% title → fragment → fragment
# ('fragment', 'fragment', 'fragment', 'title')
# 13     5           0.5% fragment → fragment → fragment → title
# ('fragment', 'fragment', 'fragment', 'fragment', 'title')
# 14     5           0.5% fragment → fragment → fragment → fragment → title
# ('citation', 'fragment')
# 15     5           0.5% citation → fragment
# ('title', 'citation', 'title')
# 16     3           0.3% title → citation → title
# ('fragment', 'title', 'title')
# 17     2           0.2% fragment → title → title
# ('fragment', 'title', 'fragment')
# 18     1           0.1% fragment → title → fragment
# ('citation', 'fragment', 'title', 'citation', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment')
# 19     1           0.1% citation → fragment → title → citation → fragment → fragment → fragment → fragment → fragment → fragment → fragment → fragment
# ('fragment', 'fragment', 'fragment')
# 20     1           0.1% fragment → fragment → fragment
# ('title', 'title', 'title')
# 21     1           0.1% title → title → title
# ('fragment', 'title', 'fragment', 'title')
# 22     1           0.1% fragment → title → fragment → title
# ('fragment', 'fragment', 'fragment', 'fragment', 'title', 'title')
# 23     1           0.1% fragment → fragment → fragment → fragment → title → title
# ('fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'title')
# 24     1           0.1% fragment → fragment → fragment → fragment → fragment → fragment → fragment → title
# ('title', 'citation', 'fragment', 'fragment', 'fragment')
# 25     1           0.1% title → citation → fragment → fragment → fragment
# ('title', 'citation', 'fragment', 'fragment', 'fragment', 'fragment')
# 26     1           0.1% title → citation → fragment → fragment → fragment → fragment
# ('title', 'citation', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment')
# 27     1           0.1% title → citation → fragment → fragment → fragment → fragment → fragment → fragment → fragment → fragment → fragment
# ('title', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment', 'fragment')
# 28     1           0.1% title → fragment → fragment → fragment → fragment → fragment → fragment → fragment → fragment
# ('citation', 'title', 'citation')
# 29     1           0.1% citation → title → citation
# ('fragment', 'fragment', 'fragment', 'title', 'fragment')
# 30     1           0.1% fragment → fragment → fragment → title → fragment
#
#
# SECONDARY SOURCES - DECONSTRUCTION PATTERNS (Ordered with Percentages)
# ====================================================================================================
# Total annotations: 269
#
# Rank   Count    %        Pattern (in order of appearance)
# ----------------------------------------------------------------------------------------------------
# ('authors', 'title', 'source')
# 1      77         28.6% authors → title → source
# ('authors', 'title', 'source', 'fragment')
# 2      67         24.9% authors → title → source → fragment
# ('authors', 'fragment')
# 3      26          9.7% authors → fragment
# ('authors',)
# 4      25          9.3% authors
# ('title',)
# 5      15          5.6% title
# ('title', 'source')
# 6      12          4.5% title → source
# ('fragment',)
# 7      10          3.7% fragment
# ('authors', 'title')
# 8      10          3.7% authors → title
# ('authors', 'title', 'fragment')
# 9      8           3.0% authors → title → fragment
# ('title', 'source', 'fragment')
# 10     7           2.6% title → source → fragment
# ('title', 'title')
# 11     2           0.7% title → title
# ('authors', 'fragment', 'fragment')
# 12     2           0.7% authors → fragment → fragment
# ('authors', 'title', 'source', 'fragment', 'fragment')
# 13     2           0.7% authors → title → source → fragment → fragment
# ('title', 'authors', 'source')
# 14     1           0.4% title → authors → source
# ('authors', 'title', 'title')
# 15     1           0.4% authors → title → title
# ('authors', 'title', 'fragment', 'fragment', 'fragment')
# 16     1           0.4% authors → title → fragment → fragment → fragment
# ('fragment', 'authors')
# 17     1           0.4% fragment → authors
# ('title', 'citation', 'fragment')
# 18     1           0.4% title → citation → fragment

# %% [markdown]
# decision_list: 1527 items
# 1278 start with title : 319 only title
# 653 have the title + citation (should be enought for disambiguation)
# the fragment is present in 734 (170 time it is alone (fragment only = hard to disambiguate))
# so decision usually start with a title 9when there is a title it is at the begining (before fragment and citation)
# legislation_list: 1006 items
# legilstation contain very often a fragment (we don't cite a legisltation without a specifique  fragment) -> 725 with 687 times it starts with the fragment. and 424 the fragment is alone (really hard to disambiguate)
# otherwise it starts with the title (290). The citation is generaly accompagnated by the title (easy for disambiguate) and represnte  89 cases.
#
# secondary_source_list: 263 items
# for the sec source. The most comun pattern is authors, title source (fragment eventually) 54%
# The fragment is presetn in 47%.1 cases (10 times alone (hard to disambiguate))
# The source is there 9supposed easy to disambiguate in 162 cases
#
# level 1 disambiguiation all is presetn (authors, title, source) (fragment or not) 55.5 (source is presente : 61.6 %)
# level 2 : withotu source, but title (eventually + authors + fragment) : 14.1
# level 3 : authors : 19.4
# level 4 : fragment only : 3.8%

# %%
def compute_annotation_statistics(decision_list, legislation_list, secondary_source_list):
    """
    Compute detailed statistics about sublabel patterns in annotations.
    Returns formatted analysis with counts and percentages.
    """
    
    def analyze_pattern_starts(annotations, label_type_name):
        """Analyze which sublabel each annotation starts with."""
        stats = {
            'total': len(annotations),
            'by_first_sublabel': {},
            'combinations': {}
        }
        
        for ann in annotations:
            sublabels = ann['all_sublabels']
            if not sublabels:
                continue
            
            # Count by first sublabel
            first = sublabels[0]
            stats['by_first_sublabel'][first] = stats['by_first_sublabel'].get(first, 0) + 1
            
            # Count by pattern (combination of unique sublabels in order)
            pattern = tuple(sublabels)
            stats['combinations'][pattern] = stats['combinations'].get(pattern, 0) + 1
        
        return stats
    
    def has_components(sublabels, components):
        """Check if sublabels contain all specified components."""
        return all(c in sublabels for c in components)
    
    print("\n" + "="*100)
    print("COMPUTED ANNOTATION STATISTICS (DECISIONS)")
    print("="*100)
    
    decision_stats = analyze_pattern_starts(decision_list, "decision")
    total_d = decision_stats['total']
    
    # Count decisions by starting sublabel
    title_starts = decision_stats['by_first_sublabel'].get('title', 0)
    fragment_starts = decision_stats['by_first_sublabel'].get('fragment', 0)
    citation_starts = decision_stats['by_first_sublabel'].get('citation', 0)
    
    # Count patterns
    title_only = sum(1 for ann in decision_list if ann['all_sublabels'] == ['title'])
    title_citation = sum(1 for ann in decision_list 
                         if set(ann['all_sublabels']) == {'title', 'citation'} 
                         and ann['all_sublabels'][0] == 'title')
    fragment_only = sum(1 for ann in decision_list if ann['all_sublabels'] == ['fragment'])
    
    print(f"\nTotal decisions: {total_d}")
    print(f"  • {title_starts} start with title ({title_starts/total_d*100:.1f}%)")
    print(f"    - {title_only} contain ONLY title ({title_only/total_d*100:.1f}%)")
    print(f"    - {title_citation} have title + citation ({title_citation/total_d*100:.1f}%)")
    print(f"  • {fragment_starts} start with fragment ({fragment_starts/total_d*100:.1f}%)")
    print(f"    - {fragment_only} contain ONLY fragment ({fragment_only/total_d*100:.1f}%)")
    print(f"  • {citation_starts} start with citation ({citation_starts/total_d*100:.1f}%)")
    
    fragment_total = sum(1 for ann in decision_list if 'fragment' in ann['all_sublabels'])
    print(f"\n  Fragment appears in {fragment_total} annotations ({fragment_total/total_d*100:.1f}%)")
    
    print("\n" + "="*100)
    print("COMPUTED ANNOTATION STATISTICS (LEGISLATION)")
    print("="*100)
    
    legis_stats = analyze_pattern_starts(legislation_list, "legislation")
    total_l = legis_stats['total']
    
    legis_title_starts = legis_stats['by_first_sublabel'].get('title', 0)
    legis_fragment_starts = legis_stats['by_first_sublabel'].get('fragment', 0)
    legis_citation_starts = legis_stats['by_first_sublabel'].get('citation', 0)
    
    fragment_only_l = sum(1 for ann in legislation_list if ann['all_sublabels'] == ['fragment'])
    title_only_l = sum(1 for ann in legislation_list if ann['all_sublabels'] == ['title'])
    title_citation_l = sum(1 for ann in legislation_list 
                           if set(ann['all_sublabels']) == {'title', 'citation'})
    
    print(f"\nTotal legislation: {total_l}")
    print(f"  • {legis_fragment_starts} start with fragment ({legis_fragment_starts/total_l*100:.1f}%)")
    print(f"    - {fragment_only_l} contain ONLY fragment ({fragment_only_l/total_l*100:.1f}%)")
    print(f"  • {legis_title_starts} start with title ({legis_title_starts/total_l*100:.1f}%)")
    print(f"    - {title_only_l} contain ONLY title ({title_only_l/total_l*100:.1f}%)")
    print(f"  • {legis_citation_starts} start with citation ({legis_citation_starts/total_l*100:.1f}%)")
    
    fragment_total_l = sum(1 for ann in legislation_list if 'fragment' in ann['all_sublabels'])
    print(f"\n  Fragment appears in {fragment_total_l} annotations ({fragment_total_l/total_l*100:.1f}%)")
    
    print("\n" + "="*100)
    print("COMPUTED ANNOTATION STATISTICS (SECONDARY SOURCES)")
    print("="*100)
    
    sec_stats = analyze_pattern_starts(secondary_source_list, "secondary sources")
    total_s = sec_stats['total']
    
    sec_authors_starts = sec_stats['by_first_sublabel'].get('authors', 0)
    sec_title_starts = sec_stats['by_first_sublabel'].get('title', 0)
    sec_fragment_starts = sec_stats['by_first_sublabel'].get('fragment', 0)
    sec_source_starts = sec_stats['by_first_sublabel'].get('source', 0)
    
    # Check "level" patterns for secondary sources
    level1 = sum(1 for ann in secondary_source_list 
                 if has_components(ann['all_sublabels'], ['authors', 'title', 'source']))
    level2 = sum(1 for ann in secondary_source_list 
                 if not has_components(ann['all_sublabels'], ['source']) 
                 and 'title' in ann['all_sublabels'])
    level3 = sum(1 for ann in secondary_source_list 
                 if not has_components(ann['all_sublabels'], ['source']) 
                 and 'title' not in ann['all_sublabels']
                 and 'authors' in ann['all_sublabels'])
    level4 = sum(1 for ann in secondary_source_list 
                 if ann['all_sublabels'] == ['fragment'])
    
    authors_title_source = sum(1 for ann in secondary_source_list
                               if set(ann['all_sublabels']) >= {'authors', 'title', 'source'})
    
    fragment_total_s = sum(1 for ann in secondary_source_list if 'fragment' in ann['all_sublabels'])
    fragment_only_s = sum(1 for ann in secondary_source_list if ann['all_sublabels'] == ['fragment'])
    source_total_s = sum(1 for ann in secondary_source_list if 'source' in ann['all_sublabels'])
    
    print(f"\nTotal secondary sources: {total_s}")
    print(f"  • {sec_authors_starts} start with authors ({sec_authors_starts/total_s*100:.1f}%)")
    print(f"  • {sec_title_starts} start with title ({sec_title_starts/total_s*100:.1f}%)")
    print(f"  • {sec_fragment_starts} start with fragment ({sec_fragment_starts/total_s*100:.1f}%)")
    print(f"  • {sec_source_starts} start with source ({sec_source_starts/total_s*100:.1f}%)")
    
    print(f"\n  Fragment appears in {fragment_total_s} annotations ({fragment_total_s/total_s*100:.1f}%)")
    print(f"    - {fragment_only_s} contain ONLY fragment ({fragment_only_s/total_s*100:.1f}%)")
    print(f"  Source appears in {source_total_s} annotations ({source_total_s/total_s*100:.1f}%)")
    print(f"  Authors + Title + Source: {authors_title_source} annotations ({authors_title_source/total_s*100:.1f}%)")
    
    print(f"\n  Disambiguation Levels:")
    print(f"    Level 1 (authors + title + source ±fragment): {level1} ({level1/total_s*100:.1f}%)")
    print(f"    Level 2 (title ±authors ±fragment, no source): {level2} ({level2/total_s*100:.1f}%)")
    print(f"    Level 3 (authors only, no title/source): {level3} ({level3/total_s*100:.1f}%)")
    print(f"    Level 4 (fragment only): {level4} ({level4/total_s*100:.1f}%)")

# Run the computation
compute_annotation_statistics(decision_list, legislation_list, secondary_source_list)
# Out:
# ====================================================================================================
# COMPUTED ANNOTATION STATISTICS (DECISIONS)
# ====================================================================================================
#
# Total decisions: 1569
#   • 1329 start with title (84.7%)
#     - 331 contain ONLY title (21.1%)
#     - 432 have title + citation (27.5%)
#   • 197 start with fragment (12.6%)
#     - 174 contain ONLY fragment (11.1%)
#   • 32 start with citation (2.0%)
#
#   Fragment appears in 766 annotations (48.8%)
#
# ====================================================================================================
# COMPUTED ANNOTATION STATISTICS (LEGISLATION)
# ====================================================================================================
#
# Total legislation: 1091
#   • 755 start with fragment (69.2%)
#     - 416 contain ONLY fragment (38.1%)
#   • 309 start with title (28.3%)
#     - 232 contain ONLY title (21.3%)
#   • 26 start with citation (2.4%)
#
#   Fragment appears in 802 annotations (73.5%)
#
# ====================================================================================================
# COMPUTED ANNOTATION STATISTICS (SECONDARY SOURCES)
# ====================================================================================================
#
# Total secondary sources: 266
#   • 219 start with authors (82.3%)
#   • 35 start with title (13.2%)
#   • 11 start with fragment (4.1%)
#   • 0 start with source (0.0%)
#
#   Fragment appears in 125 annotations (47.0%)
#     - 10 contain ONLY fragment (3.8%)
#   Source appears in 166 annotations (62.4%)
#   Authors + Title + Source: 149 annotations (56.0%)
#
#   Disambiguation Levels:
#     Level 1 (authors + title + source ±fragment): 149 (56.0%)
#     Level 2 (title ±authors ±fragment, no source): 38 (14.3%)
#     Level 3 (authors only, no title/source): 51 (19.2%)
#     Level 4 (fragment only): 10 (3.8%)

# %% [markdown]
# # Analysis of Few-Shot Examples from JSON
#
# Now analyzing the selected few-shot examples from `combined_v3_with_sources_fixed_spacing.json`

# %%
import json
from pathlib import Path
from collections import Counter, defaultdict
from bs4 import BeautifulSoup

# Load the JSON file
json_file = Path.cwd().parent / 'few_shot_selection_tool' / 'second_selected' / 'examples_selected_45.json'

print(f"Loading: {json_file.name}")
print(f"File exists: {json_file.exists()}")

with open(json_file, 'r', encoding='utf-8') as f:
    few_shot_data = json.load(f)

print(f"\nTotal examples in file: {len(few_shot_data)}")

# Filter for selected examples only
selected_examples = [item for item in few_shot_data if item.get('selected', False) == True]

print(f"Selected examples: {len(selected_examples)}")
print(f"\nFirst selected example preview:")
if selected_examples:
    print(f"  Source file: {selected_examples[0].get('source_file', 'N/A')}")
    print(f"  Output preview: {selected_examples[0]['example']['output'][:150]}...")
# Out:
# Loading: examples_selected_45.json
# File exists: True
#
# Total examples in file: 787
# Selected examples: 45
#
# First selected example preview:
#   Source file: N/A
#   Output preview:  Peter
# C. Engelmann, for the respondent Statutes Cited: <legislation> <title>Canadian
# International Trade Tribunal Act</title>, <citation>S.C. 1988, c...

# %%
def extract_annotations_from_json_output(output_text):
    """
    Extract all parent-level annotations from the JSON output field using regex.
    The output contains XML-like tags: <legislation>, <decision>, <secondary sources>
    with nested tags like <title>, <fragment>, <citation>, <source>, <authors>
    
    Returns a dict with keys: 'decision', 'legislation', 'secondary sources'
    Each value is a list of annotation dictionaries.
    """
    import re
    
    annotations = {
        'decision': [],
        'legislation': [],
        'secondary sources': []
    }
    
    # Define patterns for each label type
    # Note: 'secondary sources' has a space, so we use \s+ to match it
    label_patterns = {
        'decision': (r'<decision>', r'</decision>'),
        'legislation': (r'<legislation>', r'</legislation>'),
        'secondary sources': (r'<secondary\s+sources>', r'</secondary\s+sources>')
    }
    
    for label_type, (open_tag, close_tag) in label_patterns.items():
        # Find all occurrences of this tag with balanced opening/closing
        pos = 0
        while pos < len(output_text):
            # Find next opening tag
            open_match = re.search(open_tag, output_text[pos:], re.IGNORECASE)
            if not open_match:
                break
            
            start_pos = pos + open_match.start()
            content_start = pos + open_match.end()
            
            # Find matching closing tag by counting depth
            depth = 1
            search_pos = content_start
            
            while depth > 0 and search_pos < len(output_text):
                # Find next opening or closing tag
                next_open = re.search(open_tag, output_text[search_pos:], re.IGNORECASE)
                next_close = re.search(close_tag, output_text[search_pos:], re.IGNORECASE)
                
                open_pos = search_pos + next_open.start() if next_open else len(output_text)
                close_pos = search_pos + next_close.start() if next_close else len(output_text)
                
                if close_pos < open_pos:
                    # Found a closing tag
                    depth -= 1
                    if depth == 0:
                        # This is our matching closing tag
                        close_match_len = len(next_close.group(0))
                        end_pos = close_pos + close_match_len
                        
                        # Extract the full HTML and content
                        full_html = output_text[start_pos:end_pos]
                        content = output_text[content_start:close_pos]
                        
                        # Extract all sublabels using regex
                        all_sublabels = []
                        sublabel_names = ['title', 'fragment', 'citation', 'source', 'authors']
                        
                        for sublabel_name in sublabel_names:
                            # Count occurrences of opening sublabel tags
                            sublabel_pattern = f'<{sublabel_name}>'
                            matches = re.findall(sublabel_pattern, content, re.IGNORECASE)
                            all_sublabels.extend([sublabel_name] * len(matches))
                        
                        # Extract text content (remove all tags)
                        text_content = re.sub(r'<[^>]+>', '', content).strip()
                        # Clean up extra whitespace
                        text_content = re.sub(r'\s+', ' ', text_content)
                        
                        annotation_data = {
                            'full_html': full_html,
                            'text_content': text_content,
                            'direct_sublabels': [],  # Not computed separately
                            'all_sublabels': all_sublabels
                        }
                        
                        annotations[label_type].append(annotation_data)
                        
                        # Move position past this match
                        pos = end_pos
                        break
                    else:
                        search_pos = close_pos + len(next_close.group(0))
                elif open_pos < len(output_text):
                    # Found an opening tag (nested)
                    depth += 1
                    search_pos = open_pos + len(next_open.group(0))
                else:
                    # No more tags found
                    break
            else:
                # If we didn't find a matching closing tag, move past this opening tag
                pos = content_start
    
    return annotations

# Test the extraction on first selected example
if selected_examples:
    test_annotations = extract_annotations_from_json_output(selected_examples[0]['example']['output'])
    print("Test extraction on first example:")
    for label_type, anns in test_annotations.items():
        print(f"  {label_type}: {len(anns)} annotations")
# Out:
# Test extraction on first example:
#   decision: 0 annotations
#   legislation: 2 annotations
#   secondary sources: 0 annotations

# %%
# Process all selected examples
fewshot_annotations = {
    'decision': [],
    'legislation': [],
    'secondary sources': []
}

print("Processing selected few-shot examples...")
print("="*80)

for i, item in enumerate(selected_examples, 1):
    output_text = item['example']['output']
    annotations = extract_annotations_from_json_output(output_text)
    
    # Aggregate results
    for label_type in ['decision', 'legislation', 'secondary sources']:
        fewshot_annotations[label_type].extend(annotations[label_type])

print("\nTOTAL ANNOTATIONS FROM FEW-SHOT EXAMPLES:")
print("="*80)
for label_type in ['decision', 'legislation', 'secondary sources']:
    print(f"  {label_type}: {len(fewshot_annotations[label_type])} annotations")
print("="*80)
# Out:
# Processing selected few-shot examples...
# ================================================================================
#
# TOTAL ANNOTATIONS FROM FEW-SHOT EXAMPLES:
# ================================================================================
#   decision: 61 annotations
#   legislation: 20 annotations
#   secondary sources: 35 annotations
# ================================================================================

# %% [markdown]
# ## Preview of Few-Shot Annotations

# %%
print(f"DECISION ANNOTATIONS FROM FEW-SHOT ({len(fewshot_annotations['decision'])} total)\n")
print("="*80)

for i, annotation in enumerate(fewshot_annotations['decision'][:15], 1):
    print(f"\n[{i}]")
    print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
    print(f"    Text: {annotation['text_content'][:80]}...")
    print(f"    XML: {annotation['full_html'][:120]}...")

if len(fewshot_annotations['decision']) > 15:
    print(f"\n... and {len(fewshot_annotations['decision']) - 15} more decision annotations")
# Out:
# DECISION ANNOTATIONS FROM FEW-SHOT (61 total)
#
# ================================================================================
#
# [1]
#     Sublabels: title
#     Text: Pfizer case (supra)...
#     XML: <decision><title>Pfizer case</title> (supra)</decision>...
#
# [2]
#     Sublabels: title
#     Text: Olympia Floor and Wall Tile Company v. The Deputy Minister of National Revenue f...
#     XML: <decision><title>Olympia Floor and Wall Tile Company v. The Deputy Minister of
# National Revenue for Customs and Excise</...
#
# [3]
#     Sublabels: citation
#     Text: [1977] 1 S.C.R. 456...
#     XML: <decision><citation>[1977] 1 S.C.R. 456</citation></decision>...
#
# [4]
#     Sublabels: citation
#     Text: 2 T.B.R. 106...
#     XML: <decision><citation>2 T.B.R. 106</citation></decision>...
#
# [5]
#     Sublabels: citation
#     Text: 5 C.E.R. 562...
#     XML: <decision><citation>5 C.E.R. 562</citation></decision>...
#
# [6]
#     Sublabels: fragment
#     Text: Ibid, at p. 460...
#     XML: <decision>Ibid, at <fragment>p. 460</fragment></decision>...
#
# [7]
#     Sublabels: citation
#     Text: [1970] Ex. C.R. 828...
#     XML: <decision><citation>[1970] Ex. C.R. 828</citation></decision>...
#
# [8]
#     Sublabels: fragment
#     Text: Ibid. at p. 838...
#     XML: <decision>Ibid. at <fragment>p. 838</fragment></decision>...
#
# [9]
#     Sublabels: fragment
#     Text: Ibid., at p. 5...
#     XML: <decision>Ibid., at <fragment>p. 5</fragment></decision>...
#
# [10]
#     Sublabels: fragment
#     Text: pp. 743-44 S.C.R., p. 200 C.R.R....
#     XML: <decision><fragment>pp. 743-44</fragment> S.C.R., <fragment>p. 200</fragment>
# C.R.R.</decision>...
#
# [11]
#     Sublabels: title, fragment, citation
#     Text: R. v. Belnavis (1996), 36 C.R.R. (2d) 32 at p. 58, 107 C.C.C. (3d) 195 at pp. 22...
#     XML: <decision><title>R. v. Belnavis (1996)</title>, <citation>36 C.R.R. (2d) 32</citation> at
# <fragment>p. 58</fragment>, <c...
#
# [12]
#     Sublabels: title, fragment
#     Text: Andrews v. Law Society of British Columbia at p. 163 S.C.R., p. 219 C.R.R....
#     XML: <decision><title>Andrews
# v. Law Society of British Columbia</title> at <fragment>p. 163</fragment> S.C.R., <fragment>p. ...
#
# [13]
#     Sublabels: title, citation
#     Text: Irwin Toy Ltd. v. Quebec (Attorney General), [1989] 1 S.C.R. 927, 39 C.R.R. 193...
#     XML: <decision><title>Irwin Toy Ltd. v. Quebec
# (Attorney General)</title>, <citation>[1989] 1 S.C.R. 927</citation>, <citatio...
#
# [14]
#     Sublabels: title, citation
#     Text: R. v. Rowbotham (1988), 35 C.R.R. 207 (abridged), 41 C.C.C. (3d) 1 (Ont. C.A.)...
#     XML: <decision><title>R. v. Rowbotham (1988)</title>, <citation>35 C.R.R. 207 (abridged)</citation>, <citation>41 C.C.C. (3d)...
#
# [15]
#     Sublabels: title, fragment, citation
#     Text: Duren v. Missouri, 99 S.Ct. 664 at p. 671 (1979)...
#     XML: <decision><title>Duren v. Missouri</title>, <citation>99 S.Ct. 664</citation> at <fragment>p.
# 671</fragment> <citation>(...
#
# ... and 46 more decision annotations

# %%
print(f"LEGISLATION ANNOTATIONS FROM FEW-SHOT ({len(fewshot_annotations['legislation'])} total)\n")
print("="*80)

for i, annotation in enumerate(fewshot_annotations['legislation'][:15], 1):
    print(f"\n[{i}]")
    print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
    print(f"    Text: {annotation['text_content'][:80]}...")
    print(f"    XML: {annotation['full_html'][:120]}...")

if len(fewshot_annotations['legislation']) > 15:
    print(f"\n... and {len(fewshot_annotations['legislation']) - 15} more legislation annotations")
# Out:
# LEGISLATION ANNOTATIONS FROM FEW-SHOT (20 total)
#
# ================================================================================
#
# [1]
#     Sublabels: title, fragment, citation
#     Text: Canadian International Trade Tribunal Act, S.C. 1988, c. 56,subs.54(2) and s. 60...
#     XML: <legislation> <title>Canadian
# International Trade Tribunal Act</title>, <citation>S.C. 1988, c. 56</citation>,<fragment>...
#
# [2]
#     Sublabels: title, fragment, citation
#     Text: Excise Tax Act, R.S.C. 1970, c. E-13, paragraph 1(h), Part XII, Schedule III...
#     XML: <legislation><title>Excise
# Tax Act</title>, <citation>R.S.C. 1970, c. E-13</citation>, <fragment>paragraph 1(h), Part XI...
#
# [3]
#     Sublabels: fragment
#     Text: exemption clause...
#     XML: <legislation><fragment>exemption clause</fragment></legislation>...
#
# [4]
#     Sublabels: fragment
#     Text: exemption clause...
#     XML: <legislation><fragment>exemption clause</fragment></legislation>...
#
# [5]
#     Sublabels: citation
#     Text: S.C. 1988, c. 56...
#     XML: <legislation><citation>S.C. 1988, c. 56</citation></legislation>...
#
# [6]
#     Sublabels: title
#     Text: Juries Act...
#     XML: <legislation><title>Juries Act</title></legislation>...
#
# [7]
#     Sublabels: title, fragment
#     Text: ss. 7, 11(d) and 11(f) of the Charter...
#     XML: <legislation><fragment>ss. 7</fragment>, <fragment>11(d)</fragment> and <fragment>11(f)</fragment> of the <title>Charter...
#
# [8]
#     Sublabels: fragment
#     Text: s. 15...
#     XML: <legislation><fragment>s. 15</fragment></legislation>...
#
# [9]
#     Sublabels: title
#     Text: Criminal Code...
#     XML: <legislation><title>Criminal Code</title></legislation>...
#
# [10]
#     Sublabels: fragment
#     Text: section 18.2...
#     XML: <legislation><fragment>section
# 18.2</fragment></legislation>...
#
# [11]
#     Sublabels: title
#     Text: Charter...
#     XML: <legislation><title>Charter</title></legislation>...
#
# [12]
#     Sublabels: title, fragment, citation
#     Text: Administrative Tribunals Act, S.B.C. 2004, c. 45: see ss. 58 and 59...
#     XML: <legislation><title>Administrative Tribunals Act</title>, <citation>S.B.C. 2004, c. 45</citation>: see <fragment>ss. 58<...
#
# [13]
#     Sublabels: title, citation
#     Text: Vienna Convention on Diplomatic Relations, Can. T.S. 1966 No. 29 (“VCDR”)...
#     XML: <legislation><title>Vienna Convention on Diplomatic Relations</title>, <citation>Can. T.S. 1966 No. 29</citation> (“<tit...
#
# [14]
#     Sublabels: title
#     Text: VCDR...
#     XML: <legislation><title>VCDR</title></legislation>...
#
# [15]
#     Sublabels: title, citation
#     Text: Vienna Convention on Consular Relations, Can. T.S. 1974 No. 25...
#     XML: <legislation><title>Vienna Convention on Consular Relations</title>, <citation>Can. T.S. 1974 No. 25</citation></legisla...
#
# ... and 5 more legislation annotations

# %%
print(f"SECONDARY SOURCE ANNOTATIONS FROM FEW-SHOT ({len(fewshot_annotations['secondary sources'])} total)\n")
print("="*80)

if len(fewshot_annotations['secondary sources']) == 0:
    print("No secondary source annotations found in the selected few-shot examples.")
else:
    for i, annotation in enumerate(fewshot_annotations['secondary sources'][:15], 1):
        print(f"\n[{i}]")
        print(f"    Sublabels: {', '.join(set(annotation['all_sublabels']))}")
        print(f"    Text: {annotation['text_content'][:80]}...")
        print(f"    XML: {annotation['full_html'][:120]}...")
    
    if len(fewshot_annotations['secondary sources']) > 15:
        print(f"\n... and {len(fewshot_annotations['secondary sources']) - 15} more secondary source annotations")
# Out:
# SECONDARY SOURCE ANNOTATIONS FROM FEW-SHOT (35 total)
#
# ================================================================================
#
# [1]
#     Sublabels: title
#     Text: Funk &amp; Wagnalls New Standard Dictionary of the English Language...
#     XML: <secondary sources><title>Funk
# &amp; Wagnalls New Standard Dictionary of the English Language</title></secondary sources...
#
# [2]
#     Sublabels: title, source
#     Text: The Oxford English Dictionary (Second Edition)...
#     XML: <secondary sources><title>The Oxford
# English Dictionary</title> (<source>Second Edition</source>)</secondary sources>...
#
# [3]
#     Sublabels: title, source
#     Text: Black's Law Dictionary (Revised Fourth Edition)...
#     XML: <secondary sources><title>Black's Law Dictionary </title>(<source>Revised
# Fourth Edition</source>)</secondary sources>...
#
# [4]
#     Sublabels: title
#     Text: The Houghton Mifflin Canadian Dictionary of the English Language...
#     XML: <secondary sources><title>The Houghton Mifflin Canadian Dictionary of the English
# Language</title></secondary sources>...
#
# [5]
#     Sublabels: title
#     Text: Webster's Third New International Dictionary of the English Language Unabridged...
#     XML: <secondary sources><title>Webster's Third New International Dictionary of the English Language
# Unabridged</title></secon...
#
# [6]
#     Sublabels: title, source
#     Text: Webster's New World Dictionary (Second College Edition)...
#     XML: <secondary sources><title>Webster's New World Dictionary</title> (<source>Second College Edition</source>)</secondary so...
#
# [7]
#     Sublabels: title
#     Text: Funk &amp; Wagnalls Standard College Dictionary...
#     XML: <secondary sources><title>Funk
# &amp; Wagnalls Standard College Dictionary</title></secondary sources>...
#
# [8]
#     Sublabels: authors, title
#     Text: Ontario Ministry of Transportation and Communications (the Ontario code)...
#     XML: <secondary sources><authors>Ontario
# Ministry of Transportation and Communications </authors>(the <title>Ontario code</ti...
#
# [9]
#     Sublabels: title
#     Text: Ontario code...
#     XML: <secondary sources><title>Ontario code</title></secondary sources>...
#
# [10]
#     Sublabels: title, source
#     Text: Funk &amp; Wagnalls New Standard Dictionary of the English Language (1963)...
#     XML: <secondary sources><title>Funk &amp; Wagnalls New Standard Dictionary
# of the English Language</title> (<source>1963</sou...
#
# [11]
#     Sublabels: authors, title, source
#     Text: Driedger, E. A., Construction of Statutes (2nd ed.)...
#     XML: <secondary sources><authors>Driedger, E. A.</authors>, <title>Construction
# of Statutes</title> (<source>2nd ed.</source>...
#
# [12]
#     Sublabels: fragment
#     Text: pp. 819-20...
#     XML: <secondary sources><fragment>pp. 819-20</fragment></secondary sources>...
#
# [13]
#     Sublabels: authors, title, source
#     Text: Aperçu statistique : le système correctionnel et la mise en liberté sous conditi...
#     XML: <secondary sources><title>Aperçu statistique : le système
# correctionnel et la mise en liberté sous condition</title>, <a...
#
# [14]
#     Sublabels: authors, title, fragment, source
#     Text: J. T. Robertson, Administrative Deference: The Canadian Doctrine that Continues ...
#     XML: <secondary sources><authors>J. T. Robertson</authors>, <title>Administrative Deference: The Canadian Doctrine that Conti...
#
# [15]
#     Sublabels: authors, title, fragment, source
#     Text: D. Stratas, “The Canadian Law of Judicial Review: A Plea for Doctrinal Coherence...
#     XML: <secondary sources><authors>D. Stratas</authors>, “<title>The Canadian Law of Judicial Review: A Plea for Doctrinal Cohe...
#
# ... and 20 more secondary source annotations

# %% [markdown]
# ## Sublabel Pattern Analysis for Few-Shot Examples

# %%
# Analyze sublabel patterns for few-shot examples
print("\n" + "="*80)
print("SUBLABEL PATTERN ANALYSIS - FEW-SHOT EXAMPLES")
print("="*80)

for label_type in ['decision', 'legislation', 'secondary sources']:
    if fewshot_annotations[label_type]:
        analyze_sublabel_patterns(fewshot_annotations[label_type], label_type)
# Out:
# ================================================================================
# SUBLABEL PATTERN ANALYSIS - FEW-SHOT EXAMPLES
# ================================================================================
#
# DECISION - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   fragment: 76
#   citation: 74
#   title: 56
#
# Most common sublabel patterns:
#   ('citation', 'fragment', 'title'): 33
#   ('fragment',): 19
#   ('citation', 'title'): 10
#   ('fragment', 'title'): 7
#   ('title',): 6
#   ('citation',): 5
#   (): 3
#   ('citation', 'fragment'): 2
#
# LEGISLATION - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   fragment: 26
#   title: 22
#   citation: 7
#
# Most common sublabel patterns:
#   ('fragment', 'title'): 11
#   ('title',): 8
#   ('fragment',): 8
#   ('citation', 'fragment', 'title'): 3
#   ('citation',): 3
#
# SECONDARY SOURCES - SUBLABEL ANALYSIS
# ============================================================
#
# Most common sublabels:
#   title: 24
#   source: 17
#   authors: 17
#   fragment: 10
#
# Most common sublabel patterns:
#   ('authors', 'fragment', 'source', 'title'): 8
#   ('title',): 6
#   ('source', 'title'): 4
#   ('authors', 'source', 'title'): 4
#   ('authors',): 4
#   ('authors', 'title'): 1
#   ('fragment',): 1
#   ('fragment', 'source', 'title'): 1

# %% [markdown]
# ## Sublabel Order Analysis for Few-Shot Examples

# %%
# Analyze order for few-shot examples
print("\n" + "="*80)
print("ANALYZING SUBLABEL ORDER (which comes before which) - FEW-SHOT EXAMPLES")
print("="*80)

for label_type in ['decision', 'legislation', 'secondary sources']:
    if fewshot_annotations[label_type]:
        ordered_patterns = analyze_sublabel_order(fewshot_annotations[label_type], label_type, examples=3)
        print()  # Extra line between sections

# %% [markdown]
# ## Comparison: Manual Annotations vs Few-Shot Examples

# %%
def compare_annotation_patterns(manual_annotations, fewshot_annotations):
    """
    Compare pattern distributions between manual annotations and few-shot examples.
    """
    print("\n" + "="*80)
    print("COMPARISON: MANUAL ANNOTATIONS vs FEW-SHOT EXAMPLES")
    print("="*80)
    
    for label_type in ['decision', 'legislation', 'secondary sources']:
        print(f"\n{'='*80}")
        print(f"{label_type.upper()}")
        print(f"{'='*80}")
        
        manual = manual_annotations[label_type]
        fewshot = fewshot_annotations[label_type]
        
        print(f"\nTotal counts:")
        print(f"  Manual annotations:  {len(manual):3d}")
        print(f"  Few-shot examples:   {len(fewshot):3d}")
        
        if not manual and not fewshot:
            print(f"  No annotations of type '{label_type}' in either dataset.")
            continue
        
        # Compare sublabel frequency
        manual_sublabels = Counter()
        fewshot_sublabels = Counter()
        
        for ann in manual:
            for sublabel in ann['all_sublabels']:
                manual_sublabels[sublabel] += 1
        
        for ann in fewshot:
            for sublabel in ann['all_sublabels']:
                fewshot_sublabels[sublabel] += 1
        
        print(f"\nSublabel usage comparison:")
        print(f"  {'Sublabel':<20} {'Manual':>10} {'Few-shot':>10} {'Difference':>12}")
        print(f"  {'-'*20} {'-'*10} {'-'*10} {'-'*12}")
        
        all_sublabels = set(manual_sublabels.keys()) | set(fewshot_sublabels.keys())
        for sublabel in sorted(all_sublabels):
            manual_count = manual_sublabels.get(sublabel, 0)
            fewshot_count = fewshot_sublabels.get(sublabel, 0)
            diff = fewshot_count - manual_count
            diff_str = f"{diff:+d}" if diff != 0 else "0"
            print(f"  {sublabel:<20} {manual_count:>10} {fewshot_count:>10} {diff_str:>12}")
        
        # Compare pattern diversity
        manual_patterns = Counter()
        fewshot_patterns = Counter()
        
        for ann in manual:
            pattern = tuple(sorted(set(ann['all_sublabels'])))
            manual_patterns[pattern] += 1
        
        for ann in fewshot:
            pattern = tuple(sorted(set(ann['all_sublabels'])))
            fewshot_patterns[pattern] += 1
        
        print(f"\nPattern diversity:")
        print(f"  Manual annotations:  {len(manual_patterns)} unique patterns")
        print(f"  Few-shot examples:   {len(fewshot_patterns)} unique patterns")
        
        # Show common patterns
        print(f"\nTop 5 patterns in manual annotations:")
        for i, (pattern, count) in enumerate(manual_patterns.most_common(5), 1):
            pattern_str = ", ".join(pattern) if pattern else "(no sublabels)"
            print(f"    {i}. [{count:2d}x] {pattern_str}")
        
        print(f"\nTop 5 patterns in few-shot examples:")
        for i, (pattern, count) in enumerate(fewshot_patterns.most_common(5), 1):
            pattern_str = ", ".join(pattern) if pattern else "(no sublabels)"
            print(f"    {i}. [{count:2d}x] {pattern_str}")

# Run the comparison
compare_annotation_patterns(all_annotations, fewshot_annotations)
# Out:
# ================================================================================
# COMPARISON: MANUAL ANNOTATIONS vs FEW-SHOT EXAMPLES
# ================================================================================
#
# ================================================================================
# DECISION
# ================================================================================
#
# Total counts:
#   Manual annotations:  1527
#   Few-shot examples:    61
#
# Sublabel usage comparison:
#   Sublabel                 Manual   Few-shot   Difference
#   -------------------- ---------- ---------- ------------
#   citation                   1236         59        -1177
#   fragment                    856         56         -800
#   source                        2          0           -2
#   title                      1309         46        -1263
#
# Pattern diversity:
#   Manual annotations:  9 unique patterns
#   Few-shot examples:   6 unique patterns
#
# Top 5 patterns in manual annotations:
#     1. [416x] citation, title
#     2. [319x] title
#     3. [312x] fragment, title
#     4. [254x] citation, fragment, title
#     5. [191x] fragment
#
# Top 5 patterns in few-shot examples:
#     1. [26x] citation, fragment, title
#     2. [11x] fragment, title
#     3. [ 9x] fragment
#     4. [ 7x] citation
#     5. [ 4x] title
#
# ================================================================================
# LEGISLATION
# ================================================================================
#
# Total counts:
#   Manual annotations:  1006
#   Few-shot examples:    20
#
# Sublabel usage comparison:
#   Sublabel                 Manual   Few-shot   Difference
#   -------------------- ---------- ---------- ------------
#   citation                     97          6          -91
#   fragment                    842         22         -820
#   title                       571         15         -556
#
# Pattern diversity:
#   Manual annotations:  8 unique patterns
#   Few-shot examples:   6 unique patterns
#
# Top 5 patterns in manual annotations:
#     1. [424x] fragment
#     2. [269x] fragment, title
#     3. [218x] title
#     4. [39x] citation, fragment, title
#     5. [37x] citation, title
#
# Top 5 patterns in few-shot examples:
#     1. [ 6x] title
#     2. [ 5x] fragment
#     3. [ 3x] citation, fragment, title
#     4. [ 3x] fragment, title
#     5. [ 2x] citation, title
#
# ================================================================================
# SECONDARY SOURCES
# ================================================================================
#
# Total counts:
#   Manual annotations:  263
#   Few-shot examples:    35
#
# Sublabel usage comparison:
#   Sublabel                 Manual   Few-shot   Difference
#   -------------------- ---------- ---------- ------------
#   authors                     219         25         -194
#   citation                      1          0           -1
#   fragment                    130         26         -104
#   source                      162         18         -144
#   title                       204         28         -176
#
# Pattern diversity:
#   Manual annotations:  12 unique patterns
#   Few-shot examples:   8 unique patterns
#
# Top 5 patterns in manual annotations:
#     1. [77x] authors, source, title
#     2. [69x] authors, fragment, source, title
#     3. [29x] authors, fragment
#     4. [22x] authors
#     5. [17x] title
#
# Top 5 patterns in few-shot examples:
#     1. [11x] authors, fragment, source, title
#     2. [ 6x] authors, fragment
#     3. [ 5x] title
#     4. [ 4x] source, title
#     5. [ 3x] authors, source, title
